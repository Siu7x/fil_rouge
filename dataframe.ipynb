# %%
import pandas as pd
import mariadb # ou sqlalchemy selon ce qui est dans ton requirements.txt
from flask import render_template
from app import app, db # Supposant que db est ton objet SQLAlchemy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import mariadb # ou sqlalchemy selon ce qui est dans ton requirements.txt
#       3 from flask import render_template
#       4 from app import app, db # Supposant que db est ton objet SQLAlchemy
#
# ModuleNotFoundError: No module named 'mariadb'
